# %%
# import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import influence_plot

# %%
from google.colab import files
uploaded=files.upload() #Upload file
# Out:
#      <input type="file" id="files-c8f3591a-e6a2-46a3-978c-b2cdf314e11c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8f3591a-e6a2-46a3-978c-b2cdf314e11c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv("50_Startups.csv") #Read file

# %%
data #Complete Data
# Out:
#     R&D_Spend  Administration  Marketing_Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data.head().T #Col name
# Out:
#                          0           1          2          3          4
# R&D_Spend         165349.2    162597.7  153441.51  144372.41  142107.34
# Administration    136897.8   151377.59  101145.55  118671.85   91391.77
# Marketing_Spend   471784.1   443898.53  407934.54  383199.62  366168.42
# State             New York  California    Florida   New York    Florida
# Profit           192261.83   191792.06  191050.39  182901.99  166187.94

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D_Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing_Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
data.describe()
# Out:
#            R&D_Spend  Administration  Marketing_Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
data.dropna() #Checking any null value
# Out:
#     R&D_Spend  Administration  Marketing_Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data.isna().sum() #null value
# Out:
# R&D_Spend          0
# Administration     0
# Marketing_Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
data1=data.rename({'R&D_Spend':'RD','Administration':'ADM','Marketing_Spend':'MS'},axis=1) #Rename col name

# %%
data1 #New data
# Out:
#            RD        ADM         MS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
data1.head().T
# Out:
#                 0           1          2          3          4
# RD       165349.2    162597.7  153441.51  144372.41  142107.34
# ADM      136897.8   151377.59  101145.55  118671.85   91391.77
# MS       471784.1   443898.53  407934.54  383199.62  366168.42
# State    New York  California    Florida   New York    Florida
# Profit  192261.83   191792.06  191050.39  182901.99  166187.94

# %% [markdown]
# #Correction

# %%
data1.corr()
# Out:
#               RD       ADM        MS    Profit
# RD      1.000000  0.241955  0.724248  0.972900
# ADM     0.241955  1.000000 -0.032154  0.200717
# MS      0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %%
fig,ax=plt.subplots(figsize=(5,5))
corrMatrix = data1.corr()
sns.heatmap(corrMatrix, annot=True,cmap="YlGnBu")
plt.show()

# %% [markdown]
# #Density plot

# %%
sns.distplot(data1['RD'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data1['ADM'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data1['MS'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data1['Profit'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#pairplot
sns.set_style(style='darkgrid')
sns.pairplot(data1)

# %%
model=smf.ols("Profit~RD+ADM+MS",data=data1).fit() #Model fit

# %% [markdown]
# #Testing

# %%
model.params
# Out:
# Intercept    50122.192990
# RD               0.805715
# ADM             -0.026816
# MS               0.027228
# dtype: float64

# %%
model.tvalues , np.round(model.pvalues,5)
# Out:
# (Intercept     7.626218
#  RD           17.846374
#  ADM          -0.525507
#  MS            1.655077
#  dtype: float64, Intercept    0.00000
#  RD           0.00000
#  ADM          0.60176
#  MS           0.10472
#  dtype: float64)

# %%
model.rsquared , model.rsquared_adj
# Out:
# (0.9507459940683246, 0.9475337762901719)

# %% [markdown]
# #Sub-Group

# %%
slr_a=smf.ols("Profit~ADM",data=data1).fit()
slr_a.tvalues , slr_a.pvalues  # ADMS has in-significant pvalue
# Out:
# (Intercept    3.040044
#  ADM          1.419493
#  dtype: float64, Intercept    0.003824
#  ADM          0.162217
#  dtype: float64)

# %%
slr_m=smf.ols("Profit~MS",data=data1).fit()
slr_m.tvalues , slr_m.pvalues  # MKTS has significant pvalue
# Out:
# (Intercept    7.808356
#  MS           7.802657
#  dtype: float64, Intercept    4.294735e-10
#  MS           4.381073e-10
#  dtype: float64)

# %%
mlr_am=smf.ols("Profit~RD",data=data1).fit()
mlr_am.tvalues , mlr_am.pvalues  # varaibles have significant pvalues
# Out:
# (Intercept    19.320288
#  RD           29.151139
#  dtype: float64, Intercept    2.782697e-24
#  RD           3.500322e-32
#  dtype: float64)

# %%
mlr_am=smf.ols("Profit~ADM+MS",data=data1).fit()
mlr_am.tvalues , mlr_am.pvalues  # varaibles have significant pvalues
# Out:
# (Intercept    1.142741
#  ADM          2.467779
#  MS           8.281039
#  dtype: float64, Intercept    2.589341e-01
#  ADM          1.729198e-02
#  MS           9.727245e-11
#  dtype: float64)

# %% [markdown]
# #Model Validation
# ##Two Techniques: 1. Collinearity Check & 2. Residual Analysis

# %%
# 1) Collinearity Problem Check
# Calculate VIF = 1/(1-Rsquare) for all independent variables

rsq_r=smf.ols("RD~ADM+MS",data=data1).fit().rsquared
vif_r=1/(1-rsq_r)

rsq_a=smf.ols("ADM~RD+MS",data=data1).fit().rsquared
vif_a=1/(1-rsq_a)

rsq_m=smf.ols("MS~RD+ADM",data=data1).fit().rsquared
vif_m=1/(1-rsq_m)

# Putting the values in Dataframe format
d1={'Variables':['RD','ADM','MS'],'Vif':[vif_r,vif_a,vif_m]}
Vif_df=pd.DataFrame(d1)
Vif_df
# Out:
#   Variables       Vif
# 0        RD  2.468903
# 1       ADM  1.175091
# 2        MS  2.326773

# %% [markdown]
#  No one variable has VIF>20, No Collinearity, so consider all varaibles in Regression equation

# %% [markdown]
# #Q-Q plot

# %%
# 2) Residual Analysis
# Test for Normality of Residuals (Q-Q Plot) using residual model (model.resid)

sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid<-33000))
# Out:
# [array([49])]

# %%
# Test for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vs standardized residual values)
def standard_values(vals) : return (vals-vals.mean())/vals.std()  # User defined z = (x - mu)/sigma

# %% [markdown]
# #Scatter Plot

# %%
plt.scatter(standard_values(model.fittedvalues),standard_values(model.resid))
plt.title('Residual Plot')
plt.xlabel('standardized fitted values')
plt.ylabel('standardized residual values')
plt.show()

# %% [markdown]
# #Regression PLot

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'RD',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'MS',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'ADM',fig=fig)
plt.show()

# %% [markdown]
# #Model Deletion Diagnostics (checking Outliers or Influencers)
# ##Two Techniques : 1. Cook's Distance & 2. Leverage value

# %%
# 1. Cook's Distance: If Cook's distance > 1, then it's an outlier
# Get influencers using cook's distance
(c,_)=model.get_influence().cooks_distance

# %%
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
# Plot the influencers using the stem plot
fig=plt.figure(figsize=(10,7))
plt.stem(np.arange(len(data1)),np.round(c,10))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Index and value of influencer where C>1
np.argmax(c) , np.max(c)
# Out:
# (49, 0.2880822927543272)

# %%
# 2. Leverage Value using High Influence Points : Points beyond Leverage_cutoff value are influencers
influence_plot(model)
plt.show()

# %%
# Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints
k=data1.shape[1]
n=data1.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.36

# %%
data1[data1.index.isin([49])]
# Out:
#      RD       ADM        MS       State   Profit
# 49  0.0  116983.8  45173.06  California  14681.4

# %% [markdown]
# #Delete 49th Record

# %%
# Discard the data points which are influencers and reassign the row number (reset_index(drop=True))
data2=data1.drop(data1.index[[49]],axis=0).reset_index(drop=True)
data2
# Out:
#            RD        ADM         MS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
data2.head().T
# Out:
#                 0           1          2          3          4
# RD       165349.2    162597.7  153441.51  144372.41  142107.34
# ADM      136897.8   151377.59  101145.55  118671.85   91391.77
# MS       471784.1   443898.53  407934.54  383199.62  366168.42
# State    New York  California    Florida   New York    Florida
# Profit  192261.83   191792.06  191050.39  182901.99  166187.94

# %% [markdown]
# #Model Deletion Diagnostics and Final Model

# %%
while np.max(c)>10 :
    model=smf.ols("Profit~RD+ADM+MS",data=data2).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    data2=data2.drop(data2.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    data2
else:
    final_model=smf.ols("Profit~RD+ADM+MS",data=data2).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.9613162435129848

# %%
final_model.rsquared
# Out:
# 0.9613162435129848

# %% [markdown]
# #Model Prediction

# %%
# say New data for prediction is
new_data=pd.DataFrame({'RD':70000,"ADM":90000,"MS":140000},index=[0])
new_data
# Out:
#       RD    ADM      MS
# 0  70000  90000  140000

# %%
# Manual Prediction of Price
final_model.predict(new_data)
# Out:
# 0    108727.154753
# dtype: float64

# %%
# Automatic Prediction of Price with 90.02% accurcy
pred_y=final_model.predict(data2)
pred_y
# Out:
# 0     190716.676999
# 1     187537.122227
# 2     180575.526396
# 3     172461.144642
# 4     170863.486721
# 5     162582.583177
# 6     157741.338633
# 7     159347.735318
# 8     151328.826941
# 9     154236.846778
# 10    135507.792682
# 11    135472.855621
# 12    129355.599449
# 13    127780.129139
# 14    149295.404796
# 15    145937.941975
# 16    117437.627921
# 17    130408.626295
# 18    129129.234457
# 19    116641.003121
# 20    117097.731866
# 21    117911.019038
# 22    115248.217796
# 23    110603.139045
# 24    114051.073877
# 25    103398.054385
# 26    111547.638935
# 27    114916.165026
# 28    103027.229434
# 29    103057.621761
# 30    100656.410227
# 31     99088.213693
# 32    100325.741335
# 33     98962.303136
# 34     90552.307809
# 35     91709.288672
# 36     77080.554255
# 37     90722.503244
# 38     71433.021956
# 39     85147.375646
# 40     76625.510303
# 41     76492.145175
# 42     72492.394974
# 43     62592.049718
# 44     67025.731107
# ...

# %% [markdown]
# #R^2 values

# %%
df={'Prep_Models':['Model','Final_Model'],'Rsquared':[model.rsquared,final_model.rsquared]}
table=pd.DataFrame(df)
table
# Out:
#    Prep_Models  Rsquared
# 0        Model  0.950746
# 1  Final_Model  0.961316
